# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import classification_report, confusion_matrix  
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score 
from sklearn.impute import SimpleImputer

anex = pd.read_csv(r'C:\Users\Nina\Desktop\UNAD\I _Periodo_2024_16-01\Analisis_De_Datos\tarea 5') 
anex.head(892)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import classification_report, confusion_matrix  
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score 
from sklearn.impute import SimpleImputer

anex = pd.read_csv(r'C:\Users\Nina\Desktop\UNAD\I _Periodo_2024_16-01\Analisis_De_Datos\tarea 5') 
anex.head(892)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import classification_report, confusion_matrix  
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score 
from sklearn.impute import SimpleImputer

anex = pd.read_csv(r'C:\Users\Nina\Desktop\UNAD\I _Periodo_2024_16-01\Analisis_De_Datos\tarea 5') 
anex.head(892)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
anex['gender'] = anex['Sex'].map({'male': 1, 'female': 2})

# %%
anex.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      gender
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    1.352413
# std      0.806057   49.693429    0.477990
# min      0.000000    0.000000    1.000000
# 25%      0.000000    7.910400    1.000000
# 50%      0.000000   14.454200    1.000000
# 75%      0.000000   31.000000    2.000000
# ...

# %%
pmv = anex ['Age'].max() 
print("la persona mas longeva tiene:", pmv)
# Out:
# la persona mas longeva tiene: 80.0

# %%
pmj = anex ['Age'].min()
print("la persona mas joven tiene:", pmj)
# Out:
# la persona mas joven tiene: 0.42

# %%
datos_fuera_rango = anex[(anex['Age'] < 1) | (anex['Age'] > 80)]

# %%
cantidad_fuera_rango = len(datos_fuera_rango)

# %%
print("Cantidad de datos fuera del rango de edad (1 a 80 años):", cantidad_fuera_rango)
# Out:
# Cantidad de datos fuera del rango de edad (1 a 80 años): 7

# %%
niños_menores_un_año = anex[(anex['Age'] < 1) & (anex['Survived'] == 1)]

# %%
print("Niños menores de un año que sobrevivieron:")
print(ninos_menores_un_año)
# Out:
# Niños menores de un año que sobrevivieron:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked  gender
# 78   0.83      0      2  248738   29.0000      NaN        S       1
# 305  0.92      1      2  113781  151.5500  C22 C26        S       1
# 469  0.75      2      1    2666   19.2583      NaN        C       2
# ...

# %%
cantidad_sobrevivientes = (anex['Survived']==1).sum()

# Mostrar la cantidad de sobrevivientes
print("Cantidad de sobrevivientes en todo el dataset:", cantidad_sobrevivientes)
# Out:
# Cantidad de sobrevivientes en todo el dataset: 342

# %%
sobrevivientes_por_genero = anex[anex['Survived'] == 1].groupby('gender').size()

# Mostrar la cantidad de sobrevivientes por género
print("Cantidad de sobrevivientes mujeres:", sobrevivientes_por_genero.get(2, 0))  # 2 representa mujeres
print("Cantidad de sobrevivientes hombres:", sobrevivientes_por_genero.get(1, 0))  # 1 representa hombres
# Out:
# Cantidad de sobrevivientes mujeres: 233
# Cantidad de sobrevivientes hombres: 109

# %%
total_mujeres = (anex['gender'] == 2).sum()
total_hombres = (anex['gender'] == 1).sum()

# Mostrar la cantidad total de mujeres y hombres
print("Total de mujeres en el dataset:", total_mujeres)
print("Total de hombres en el dataset:", total_hombres)
# Out:
# Total de mujeres en el dataset: 314
# Total de hombres en el dataset: 577

# %%
fig, axs = plt.subplots(2,3, figsize = (15,9))
plt1 = sns.boxplot(anex['PassengerId'], ax = axs[0,0])
plt2 = sns.boxplot(anex['Survived'], ax = axs[0,1])
plt3 = sns.boxplot(anex['Pclass'], ax = axs[0,2])
plt1 = sns.boxplot(anex['Age'], ax = axs[1,0])
plt2 = sns.boxplot(anex['SibSp'], ax = axs[1,1]) 
plt3 = sns.boxplot(anex['gender'], ax = axs[1,2])  



plt.tight_layout()

# %%
print("cantidad de datos con cero registros en passengerId: ",anex['PassengerId'].isin([0]).sum())  
print("cantidad de datos con cero registros en Survived: ",anex['Survived'].isin([0]).sum())
print("cantidad de datos con cero registros en Pclass: ",anex['Pclass'].isin([0]).sum())
print("cantidad de datos con cero registros en Age: ",anex['Age'].isin([0]).sum())
print("cantidad de datos con cero registros en Sibsp: ",anex['SibSp'].isin([0]).sum())
print("cantidad de datos con cero registros en Parch: ",anex['Parch'].isin([0]).sum()) 
print("cantidad de datos con cero registros en Fare: ",anex['Fare'].isin([0]).sum()) 
print("cantidad de datos con cero registros en Sex: ",anex['Sex'].isin([0]).sum()) 
print("cantidad de datos con cero registros en Name: ",anex['Name'].isin([0]).sum()) 
print("cantidad de datos con cero registros en Ticket: ",anex['Ticket'].isin([0]).sum()) 
print("cantidad de datos con cero registros en Cabin: ",anex['Cabin'].isin([0]).sum())
# Out:
# cantidad de datos con cero registros en passengerId:  0
# cantidad de datos con cero registros en Survived:  549
# cantidad de datos con cero registros en Pclass:  0
# cantidad de datos con cero registros en Age:  0
# cantidad de datos con cero registros en Sibsp:  608
# cantidad de datos con cero registros en Parch:  678
# cantidad de datos con cero registros en Fare:  15
# cantidad de datos con cero registros en Sex:  0
# cantidad de datos con cero registros en Name:  0
# cantidad de datos con cero registros en Ticket:  0
# cantidad de datos con cero registros en Cabin:  0

# %%
imputer = SimpleImputer(strategy='most_frequent')
anex['Age'] = imputer.fit_transform(anex[['Age']]) 
print(anex['Age'].isna().sum())
# Out:
# 0

# %%
anex = anex[['Survived', 'Age', 'Pclass', 'gender']]
t = anex.drop('Survived',axis=1)
te = anex['Survived']
t_train, t_test, te_train, te_test = train_test_split(t, te, test_size=0.25, random_state= 0)

# %%
modelo_regresion = LinearRegression() 
modelo_regresion.fit (t_train , te_train)   
Prediccion = modelo_regresion.predict(t_test) 
print (t_train)
# Out:
#       Age  Pclass  gender
# 105  28.0       3       1
# 68   17.0       3       2
# 253  30.0       3       1
# 320  22.0       3       1
# 706  45.0       2       2
# ..    ...     ...     ...
# 835  39.0       1       2
# 192  19.0       3       2
# 629  24.0       3       1
# 559  36.0       3       2
# 684  60.0       2       1
#
# [668 rows x 3 columns]

# %%
print (te_train)
# Out:
# 105    0
# 68     1
# 253    0
# 320    0
# 706    1
#       ..
# 835    1
# 192    1
# 629    0
# 559    1
# 684    0
# Name: Survived, Length: 668, dtype: int64

# %%
rl = LinearRegression()
rl.fit(t_train, te_train)
Prediccion = rl.predict(t_test)

# %%
print (te_test)
# Out:
# 495    0
# 648    0
# 278    0
# 31     1
# 255    1
#       ..
# 167    0
# 306    1
# 379    0
# 742    1
# 10     1
# Name: Survived, Length: 223, dtype: int64

# %%
print (Prediccion)
# Out:
# [ 1.13032531e-01  1.13032531e-01  1.92708546e-01  9.65596775e-01
#   5.96272596e-01  4.58922588e-01  8.90607584e-01  9.32789004e-01
#   4.54235763e-01  6.19706718e-01  1.03658883e-01  7.17662556e-01
#   1.13032531e-01  8.72327761e-01  9.65596775e-01  6.66574962e-01
#   1.17719356e-01  3.09411681e-01  6.14774631e-02  2.23547850e-01
#   3.14098506e-01  9.74970423e-01  1.13032531e-01  4.58922588e-01
#   6.29080367e-01  8.90607584e-01  7.55379362e-02  6.29080367e-01
#   7.87964922e-01  7.22816855e-01  7.08511118e-02  6.70794312e-01
#   9.42852338e-02  4.58922588e-01  8.95984094e-02  4.21427992e-01
#   2.39828680e-02  2.67230262e-01  2.81290735e-01  1.45372828e-01
#   2.90196910e-01  1.08345707e-01  1.13032531e-01  1.59900775e-01
#   9.14041706e-01  1.13032531e-01  1.13032531e-01  9.93717721e-01
#   2.15675194e-01  3.27691505e-01  4.58922588e-01  4.63609412e-01
#   8.86388234e-01  1.36466653e-01  4.58922588e-01  2.85977559e-01
# ...

# %%
mse = mean_squared_error(te_test, Prediccion)
print("Error cuadrático medio:", mse)
# Out:
# Error cuadrático medio: 0.140728587711934

# %%
r2 = r2_score(te_test, Prediccion)
print("Coeficiente de determinación (R-cuadrado):", r2)
# Out:
# Coeficiente de determinación (R-cuadrado): 0.4006259045626269

# %%
plt.figure(figsize=(8, 6))
plt.scatter(te_test, Prediccion, color='blue')
plt.plot([te_test.min(), te_test.max()], [te_test.min(), te_test.max()], 'k--', lw=2)  # Línea diagonal para referencia
plt.xlabel('Valor Real')
plt.ylabel('Predicción')
plt.title('Gráfico de Dispersión: Valor Real vs. Predicción')
plt.show()

# %%
residuos = te_test - Prediccion
# Crear un histograma de los residuos
plt.figure(figsize=(8, 6))
plt.hist(residuos, bins=30, color='green', edgecolor='black')
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()
